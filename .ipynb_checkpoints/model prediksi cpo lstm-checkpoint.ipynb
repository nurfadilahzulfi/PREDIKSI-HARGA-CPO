# %%
# import library yang dibutukan dan disesuaikan untuk dataset yang bersarang dan dalam bentuk json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
import json
import datetime
import os

# TensorFlow/Keras
try:
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Dense, LSTM, Dropout
    print("✅ Menggunakan tensorflow.keras")
except ImportError:
    try:
        from keras.models import Sequential
        from keras.layers import Dense, LSTM, Dropout
        print("✅ Menggunakan keras standalone")
    except ImportError:
        print("❌ Error: Tidak dapat mengimpor Keras/TensorFlow")
        exit(1)

# Pickle & Joblib
try:
    import pickle
    PICKLE_AVAILABLE = True
    print("✅ Pickle tersedia")
except ImportError:
    PICKLE_AVAILABLE = False
    print("⚠️ Pickle tidak tersedia")

try:
    import joblib
    JOBLIB_AVAILABLE = True
    print("✅ Joblib tersedia")
except ImportError:
    JOBLIB_AVAILABLE = False
    print("⚠️ Joblib tidak tersedia")

if not PICKLE_AVAILABLE and not JOBLIB_AVAILABLE:
    print("❌ Error: Tidak ada library untuk menyimpan scaler (pickle atau joblib)")
    exit(1)

# Tampilkan semua kolom
pd.set_option('display.max_columns', None)

print("🚀 Memulai program training dan ekspor model LSTM...")
print("="*60)
# Out:
# ✅ Menggunakan tensorflow.keras
# ✅ Pickle tersedia
# ✅ Joblib tersedia
# 🚀 Memulai program training dan ekspor model LSTM...
# ...

# %%
# ===================== LOAD & EKSTRAK DATASET =====================
try:
    with open("dataset_cpo.json", "r") as file:
        raw_data = json.load(file)

    records = []
    for year in raw_data["data"]["years"]:
        for month in year["months"]:
            for entry in month["detail"]:
                if entry["value"] == 0:
                    continue
                records.append({
                    "Tanggal": entry["tanggal"],
                    "Penetapan_Harga": entry["value"]
                })

    df = pd.DataFrame(records)
    print("✅ Dataset berhasil dimuat dan diekstrak")

    # ✅ Tambahan: tampilkan 10 data pertama
    print("\n🔍 Contoh 10 data pertama:")
    print(df.head(10))

except Exception as e:
    print(f"❌ Gagal memuat dataset: {e}")
    exit(1)
# Out:
# ✅ Dataset berhasil dimuat dan diekstrak
#
# 🔍 Contoh 10 data pertama:
#       Tanggal  Penetapan_Harga
# 0  2024-05-02          12050.0
# 1  2024-05-03          11978.0
# 2  2024-05-06          12018.0
# 3  2024-05-07          12182.0
# 4  2024-05-08          12155.0
# 5  2024-05-13          12116.0
# 6  2024-05-14          12108.0
# 7  2024-05-15          12156.0
# 8  2024-05-16          12021.0
# 9  2024-05-17          12190.0

# %%
# ===================== KONVERSI DAN SORT =====================
try:
    df['Tanggal'] = pd.to_datetime(df['Tanggal'])
    df['Penetapan_Harga'] = pd.to_numeric(df['Penetapan_Harga'])
    print("✅ Konversi data berhasil")
except Exception as e:
    print(f"❌ Error konversi data: {e}")
    exit(1)

df = df.sort_values('Tanggal').reset_index(drop=True)

print(f"📊 Total data: {len(df)} records")
print(f"📅 Rentang tanggal: {df['Tanggal'].min()} - {df['Tanggal'].max()}")
print(f"💰 Rentang harga: Rp {df['Penetapan_Harga'].min():,.0f} - Rp {df['Penetapan_Harga'].max():,.0f}")

# ===================== VISUALISASI =====================
plt.figure(figsize=(14, 5))
plt.plot(df['Tanggal'], df['Penetapan_Harga'], label='Harga CPO', color='blue', linewidth=1)
plt.title("Harga CPO dari Waktu ke Waktu")
plt.xlabel("Tanggal")
plt.ylabel("Harga (Rp)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ===================== PERSIAPAN DATA =====================
print("\n🔄 Memproses data untuk training...")
data = df[['Penetapan_Harga']].values

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)
print("✅ Normalisasi data selesai")

def create_dataset(dataset, window_size=60):
    X, y = [], []
    for i in range(window_size, len(dataset)):
        X.append(dataset[i - window_size:i, 0])
        y.append(dataset[i, 0])
    return np.array(X), np.array(y)

window_size = 90
X, y = create_dataset(scaled_data, window_size)
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

print(f"📊 Data training: {X_train.shape[0]} samples")
print(f"📊 Data testing : {X_test.shape[0]} samples")

# ===================== BANGUN MODEL =====================
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(X.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(128, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
print("✅ Model berhasil dibuat")

# ===================== TRAINING =====================
print("\n🎯 Training model...")
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_data=(X_test, y_test), verbose=1)
print("✅ Training selesai!")

# ===================== EVALUASI =====================
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
r2 = r2_score(y_test_inv, y_pred_inv)

print(f"📈 RMSE     : Rp {rmse:,.2f}")
print(f"📈 R² Score : {r2 * 100:.2f}%")

# ===================== EKSPOR MODEL =====================
print("\n💾 Menyimpan model dan data...")

try:
    model.save('cpo_lstm_model.h5')
    print("✅ Model disimpan sebagai 'cpo_lstm_model.h5'")
except Exception as e:
    print(f"❌ Gagal menyimpan model: {e}")

try:
    if PICKLE_AVAILABLE:
        with open('scaler.pkl', 'wb') as f:
            pickle.dump(scaler, f)
        print("✅ Scaler disimpan (pickle)")
    elif JOBLIB_AVAILABLE:
        joblib.dump(scaler, 'scaler.joblib')
        print("✅ Scaler disimpan (joblib)")
except Exception as e:
    print(f"❌ Gagal menyimpan scaler: {e}")

try:
    df.to_csv('processed_cpo_data.csv', index=False)
    print("✅ Dataset diproses disimpan")
except Exception as e:
    print(f"❌ Gagal simpan dataset: {e}")

try:
    np.save('last_data_for_prediction.npy', scaled_data[-window_size:].reshape(1, window_size, 1))
    print("✅ Data terakhir disimpan untuk prediksi")
except Exception as e:
    print(f"❌ Gagal menyimpan data prediksi: {e}")

try:
    with open('training_history.json', 'w') as f:
        json.dump({
            'loss': list(map(float, history.history['loss'])),
            'val_loss': list(map(float, history.history['val_loss']))
        }, f, indent=4)
    print("✅ History training disimpan")
except Exception as e:
    print(f"❌ Gagal menyimpan history: {e}")
# Out:
# ✅ Konversi data berhasil
# 📊 Total data: 301 records
# 📅 Rentang tanggal: 2024-05-02 00:00:00 - 2025-07-30 00:00:00
# 💰 Rentang harga: Rp 11,978 - Rp 16,000
# 🔄 Memproses data untuk training...
# ✅ Normalisasi data selesai
# 📊 Data training: 168 samples
# 📊 Data testing : 43 samples
# ✅ Model berhasil dibuat
#
# 🎯 Training model...
# Epoch 1/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 315ms/step - loss: 0.1265 - val_loss: 0.0047
# Epoch 2/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - loss: 0.0402 - val_loss: 0.0126
# Epoch 3/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - loss: 0.0208 - val_loss: 0.0080
# Epoch 4/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 227ms/step - loss: 0.0197 - val_loss: 0.0057
# Epoch 5/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.0183 - val_loss: 0.0032
# Epoch 6/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 548ms/step - loss: 0.0139 - val_loss: 0.0037
# Epoch 7/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step - loss: 0.0137 - val_loss: 0.0029
# Epoch 8/150
# ...

# %%
# ===================== VISUALISASI HASIL =====================
plt.figure(figsize=(15, 6))
test_dates = df['Tanggal'][-len(y_test):].values
plt.plot(test_dates, y_test_inv, label='Actual', color='blue')
plt.plot(test_dates, y_pred_inv, label='Predicted', color='red')
plt.title(f"Prediksi vs Aktual Harga CPO\nRMSE: Rp {rmse:,.0f}, R²: {r2*100:.1f}%")
plt.xlabel("Tanggal")
plt.ylabel("Harga (Rp)")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
